# %%
#Pkg.add("RDatasets")
#Pkg.add("Dataframe")
#Pkg.add("Gadfly")
using RDatasets, DataFrames, Gadfly
set_default_plot_size(5inch, 5inch/golden)
describe(dataset("datasets","iris"))
plot(dataset("datasets","iris"), x="SepalWidth", y="SepalLength",color="Species")
# Out:
# SepalLength
# Summary Stats:
# Mean:           5.843333
# Minimum:        4.300000
# 1st Quartile:   5.100000
# Median:         5.800000
# 3rd Quartile:   6.400000
# Maximum:        7.900000
# Length:         150
# Type:           Float64
# Number Missing: 0
# % Missing:      0.000000
#
# SepalWidth
# Summary Stats:
# Mean:           3.057333
# Minimum:        2.000000
# 1st Quartile:   2.800000
# Median:         3.000000
# 3rd Quartile:   3.300000
# Maximum:        4.400000
# Length:         150
# Type:           Float64
# Number Missing: 0
# % Missing:      0.000000
#
# PetalLength
# Summary Stats:
# Mean:           3.758000
# Minimum:        1.000000
# 1st Quartile:   1.600000
# Median:         4.350000
# 3rd Quartile:   5.100000
# Maximum:        6.900000
# Length:         150
# Type:           Float64
# Number Missing: 0
# % Missing:      0.000000
#
# PetalWidth
# Summary Stats:
# Mean:           1.199333
# Minimum:        0.100000
# 1st Quartile:   0.300000
# Median:         1.300000
# 3rd Quartile:   1.800000
# Maximum:        2.500000
# Length:         150
# Type:           Float64
# Number Missing: 0
# % Missing:      0.000000
#
# Species
# Summary Stats:
# Length:         150
# Type:           String
# Number Unique:  3
# Number Missing: 0
# % Missing:      0.000000
# Plot(...)

# %%
using Gadfly
srand(111)
plot(x=rand(7), y=rand(7))
# Out:
# INFO: Recompiling stale cache file /Users/ToomeyD/.julia/lib/v0.6/Cairo.ji for module Cairo.
# INFO: Recompiling stale cache file /Users/ToomeyD/.julia/lib/v0.6/Gadfly.ji for module Gadfly.
# Plot(...)

# %%
using Gadfly
srand(111)
plot(x=rand(77), Geom.histogram(bincount=10))
# Out:
# Plot(...)

# %%
using Winston
srand(111)
pl = plot(cumsum(rand(111) .- 0.5), "g", cumsum(rand(111) .- 0.5), "b")
display(pl)
# Out:
# Winston.FramedPlot(...)

# %%
using Vega, Compat, Patchwork
Patchwork.load_js_runtime()
stock = ["chairs", "tables", "desks", "rugs", "lamps"]
quantity = [15, 10, 10, 5, 20]
piechart(x=stock, y=quantity)
# Out:
# INFO: Precompiling module Vega.
#
# WARNING: deprecated syntax "abstract AbstractVegaType" at /Users/ToomeyD/.julia/v0.6/Vega/src/primitives/definetypes.jl:2.
# Use "abstract type AbstractVegaType end" instead.
# ERROR: LoadError: LoadError: UndefVarError: call not defined
# Stacktrace:
#  [1] include_from_node1(::String) at ./loading.jl:576
#  [2] include(::String) at ./sysimg.jl:14
#  [3] include_from_node1(::String) at ./loading.jl:576
#  [4] include(::String) at ./sysimg.jl:14
#  [5] anonymous at ./<missing>:2
# while loading /Users/ToomeyD/.julia/v0.6/Vega/src/primitives/definetypes.jl, in expression starting on line 3
# while loading /Users/ToomeyD/.julia/v0.6/Vega/src/Vega.jl, in expression starting on line 30
# Failed to precompile Vega to /Users/ToomeyD/.julia/lib/v0.6/Vega.ji.
#
# Stacktrace:
#  [1] compilecache(::String) at ./loading.jl:710
#  [2] _require(::Symbol) at ./loading.jl:497
#  [3] require(::Symbol) at ./loading.jl:405
#  [4] include_string(::String, ::String) at ./loading.jl:522
